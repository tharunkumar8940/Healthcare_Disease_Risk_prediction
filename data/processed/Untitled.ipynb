# %%
processed_data = X.copy()
processed_data["Disease_Risk"] = y

processed_data.to_csv(
    "../data/processed/healthcare_disease_risk_processed.csv",
    index=False
)

print("Processed dataset saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 processed_data = X.copy()
#       2 processed_data["Disease_Risk"] = y
#       4 processed_data.to_csv(
#       5     "../data/processed/healthcare_disease_risk_processed.csv",
#       6     index=False
#       7 )
#
# NameError: name 'X' is not defined
